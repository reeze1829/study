# %%
# 3. 좌석 좌표 데이터 확인 (config.py 연동)
for coordinate in config.PARKING_COORDINATES:
    # 왼쪽 꼭짓점(x,y) ROI의 너비(w) ROI의 높이(h) 좌석기준
    x = int(coordinate[0])
    y = int(coordinate[1])
    w = int(coordinate[2])
    h = int(coordinate[3])

    # 오른쪽 하단 좌표
    bottom_right_x = x + w
    bottom_right_y = y + h

def mouse_control(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        x1, y1 = x, y
        print(f"시작좌표 : ({x}, {y})")
    elif event == cv2.EVENT_LBUTTONUP:
        x2, y2 = x, y
        print(f"종료좌표 : ({x}, {y})")
